# %% [markdown]
# # Drawing on Images

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
blank_image = np.zeros(shape = (512,512,3), dtype = np.int16)
plt.imshow(blank_image)

# %% [markdown]
# # Rectangle/ Square/ Line/ Circle

# %%
cv2.rectangle(blank_image, (300,10), (400, 90), color = (255,0,0), thickness = 5)
plt.imshow(blank_image)

# %%
cv2.circle(blank_image, center = (400,200), radius = 50, color = (0,0,255), thickness = 7)
plt.imshow(blank_image)

# %% [markdown]
# # Filled Geometrical shape --> thickness = -1

# %%
cv2.circle(blank_image, center = (100,400), radius = 70, color = (0,255,255), thickness = -1)
plt.imshow(blank_image)

# %%
cv2.line(blank_image, pt1 = (0,0), pt2 = (512,512), color = (0,255,0), thickness = 6)
plt.imshow(blank_image)

# %% [markdown]
# #  Text

# %%
cv2.putText(blank_image, "METU", (200,400), fontFace = cv2.FONT_HERSHEY_COMPLEX, fontScale = 2, color = (255,20,147) , thickness = 3, lineType = cv2.LINE_4)
plt.imshow(blank_image)

# %% [markdown]
# #  Polygone

# %%
blank_img = np.zeros((512,512,3), dtype = np.int32)
plt.imshow(blank_img)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype = np.int32)
pts = vertices.reshape((-1,1,2)) # Adds 3rd dimension to vertices
                                 # Not need to know what exactly it does, just for openCV purposes
                                 # Can be searched for advance knowledge

# %%
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]])

# %%
pts.shape
# Out:
# (4, 1, 2)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
cv2.polylines(blank_img, [vertices], isClosed = True, color = (255,255,255), thickness = 4)
plt.imshow(blank_img)
