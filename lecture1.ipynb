# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("C:/Users/Legion/Desktop/Python/udemy-open-cv-course/Udemy-Open-Cv/puppy.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img2= cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
plt.imshow(img2)

# %%
img3= cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img3)
