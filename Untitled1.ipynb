# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("C:/Users/Legion/Desktop/Python/udemy-open-cv-course/Udemy-Open-Cv/puppy.jpg")

# %%
img
# Out:
# array([[[102, 174, 198],
#         [102, 174, 198],
#         [102, 174, 198],
#         ...,
#         [119, 143, 179],
#         [122, 144, 180],
#         [123, 145, 181]],
#
#        [[102, 174, 198],
#         [102, 174, 198],
#         [102, 174, 198],
#         ...,
#         [119, 143, 179],
#         [122, 144, 180],
#         [122, 144, 180]],
#
#        [[102, 174, 198],
#         [102, 174, 198],
#         [102, 174, 198],
#         ...,
#         [119, 143, 179],
#         [122, 144, 180],
#         [122, 144, 180]],
#
#        ...,
#
#        [[ 30, 176, 128],
#         [ 30, 175, 130],
#         [ 33, 176, 131],
#         ...,
#         [123, 147, 189],
#         [123, 147, 189],
#         [123, 147, 189]],
#
#        [[ 28, 176, 128],
#         [ 30, 176, 128],
#         [ 31, 176, 131],
#         ...,
#         [122, 146, 188],
#         [123, 147, 189],
#         [123, 147, 189]],
#
#        [[ 28, 176, 128],
#         [ 31, 177, 129],
#         [ 31, 177, 129],
# ...

# %%
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray = cv2.imread("C:/Users/Legion/Desktop/Python/udemy-open-cv-course/Udemy-Open-Cv/puppy.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_new = cv2.resize(img_rgb,(1200,500))
plt.imshow(img_new)

# %%
width_ratio = 0.2
height_ratio = 0.2
img_ratio = cv2.resize(img_rgb, (0,0), img_rgb, width_ratio, height_ratio)
plt.imshow(img_ratio)
